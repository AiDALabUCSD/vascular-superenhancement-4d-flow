# %%
from vascular_superenhancement.utils.path_config import load_path_config
from vascular_superenhancement.data_management.patients import Patient

# Load config and create patient
path_config = load_path_config("all_patients")  # or your config name
patient = Patient(
    path_config=path_config,
    phonetic_id="Amifer",  # replace with your test patient
    overwrite_images=False,    # set to True to regenerate even if files exist
    debug=True,               # enable verbose logging
)

# Run just the per-timepoint pipeline
patient.build_per_timepoint_images()
# Out:
# Found project root at: /mnt/yeluru/vascular-superenhancement-4d-flow
# 2026-01-29 23:53:47,399 - DEBUG - Patient Amifer log file: /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/sample_patients/logs/patients/Amifer.log
# 2026-01-29 23:53:47,412 - DEBUG - Converted 3D Cine series number to integer: 900
# 2026-01-29 23:53:47,412 - DEBUG - Successfully initialized Amifer from database
# 2026-01-29 23:53:47,413 - INFO - Building per-timepoint volumes for patient Amifer
# 2026-01-29 23:53:47,413 - INFO - Building 3D cine volumes for each timepoint for patient Amifer
# 2026-01-29 23:53:47,413 - INFO - Output directory /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/3d_cine_Amifer_per_timepoint already exists and overwrite_images is False, skipping
# 2026-01-29 23:53:47,413 - INFO - Number of files in output directory: 20
# 2026-01-29 23:53:47,413 - INFO - Successfully built 3d cine per timepoint for patient Amifer
# 2026-01-29 23:53:47,413 - INFO - Building 4D flow volumes for each timepoint and component for patient Amifer
# 2026-01-29 23:53:47,495 - INFO - Loaded existing DICOM catalog for patient Amifer
# 2026-01-29 23:53:47,496 - INFO - Working on /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_mag_Amifer.nii.gz
# 2026-01-29 23:53:47,496 - INFO - Output directory /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_mag_Amifer_per_timepoint already exists and overwrite_images is False, skipping
# 2026-01-29 23:53:47,496 - INFO - Number of files in output directory: 20
# 2026-01-29 23:53:47,496 - INFO - Working on /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vx_Amifer.nii.gz
# 2026-01-29 23:53:47,496 - INFO - Output directory /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vx_Amifer_per_timepoint already exists and overwrite_images is False, skipping
# 2026-01-29 23:53:47,496 - INFO - Number of files in output directory: 20
# 2026-01-29 23:53:47,496 - INFO - Working on /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vy_Amifer.nii.gz
# 2026-01-29 23:53:47,496 - INFO - Output directory /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vy_Amifer_per_timepoint already exists and overwrite_images is False, skipping
# 2026-01-29 23:53:47,496 - INFO - Number of files in output directory: 20
# 2026-01-29 23:53:47,496 - INFO - Working on /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vz_Amifer.nii.gz
# 2026-01-29 23:53:47,496 - INFO - Output directory /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vz_Amifer_per_timepoint already exists and overwrite_images is False, skipping
# 2026-01-29 23:53:47,496 - INFO - Number of files in output directory: 20
# 2026-01-29 23:53:47,497 - INFO - Successfully built 4D flow volumes for each timepoint and component for patient Amifer
# 2026-01-29 23:53:47,497 - INFO - Successfully built 4d flow per timepoint for patient Amifer
# 2026-01-29 23:53:47,497 - INFO - Building speed volumes for each timepoint for patient Amifer
# 2026-01-29 23:53:47,497 - INFO - Output directory /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_speed_Amifer_per_timepoint already exists and overwrite_images is False, skipping
# 2026-01-29 23:53:47,497 - INFO - Number of files in output directory: 20
# 2026-01-29 23:53:47,497 - INFO - Successfully built speed per timepoint for patient Amifer
# 2026-01-29 23:53:47,497 - INFO - Building 4D flow volumes for each timepoint (full FOV) for patient Amifer
# 2026-01-29 23:53:47,655 - INFO - Working on /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_mag_Amifer.nii.gz (full FOV)
# 2026-01-29 23:53:47,655 - INFO - Building per timepoint volumes for patient Amifer
# 2026-01-29 23:53:47,655 - INFO - Loading image from /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_mag_Amifer.nii.gz
# 2026-01-29 23:53:48,907 - INFO - Image dimensions: (256, 256, 152, 20)
# 2026-01-29 23:53:49,174 - INFO - Loaded 20 timepoints
# 2026-01-29 23:53:54,916 - INFO - Saved 20 timepoints for 4d_flow_mag_Amifer
# 2026-01-29 23:53:54,974 - INFO - Working on /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vx_Amifer.nii.gz (full FOV)
# 2026-01-29 23:53:54,975 - INFO - Building per timepoint volumes for patient Amifer
# 2026-01-29 23:53:54,975 - INFO - Loading image from /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vx_Amifer.nii.gz
# 2026-01-29 23:53:56,111 - INFO - Image dimensions: (256, 256, 152, 20)
# 2026-01-29 23:53:56,422 - INFO - Loaded 20 timepoints
# 2026-01-29 23:54:01,387 - INFO - Saved 20 timepoints for 4d_flow_vx_Amifer
# 2026-01-29 23:54:01,446 - INFO - Working on /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vy_Amifer.nii.gz (full FOV)
# 2026-01-29 23:54:01,446 - INFO - Building per timepoint volumes for patient Amifer
# 2026-01-29 23:54:01,446 - INFO - Loading image from /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vy_Amifer.nii.gz
# 2026-01-29 23:54:02,573 - INFO - Image dimensions: (256, 256, 152, 20)
# 2026-01-29 23:54:02,844 - INFO - Loaded 20 timepoints
# 2026-01-29 23:54:07,781 - INFO - Saved 20 timepoints for 4d_flow_vy_Amifer
# 2026-01-29 23:54:07,839 - INFO - Working on /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vz_Amifer.nii.gz (full FOV)
# 2026-01-29 23:54:07,839 - INFO - Building per timepoint volumes for patient Amifer
# 2026-01-29 23:54:07,839 - INFO - Loading image from /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vz_Amifer.nii.gz
# 2026-01-29 23:54:08,975 - INFO - Image dimensions: (256, 256, 152, 20)
# 2026-01-29 23:54:09,266 - INFO - Loaded 20 timepoints
# 2026-01-29 23:54:14,285 - INFO - Saved 20 timepoints for 4d_flow_vz_Amifer
# 2026-01-29 23:54:14,344 - INFO - Successfully built 4D flow volumes (full FOV) for each timepoint for patient Amifer
# 2026-01-29 23:54:14,344 - INFO - Successfully built 4d flow per timepoint (full FOV) for patient Amifer
# 2026-01-29 23:54:14,344 - INFO - Building 3D cine per timepoint (full FOV) for patient Amifer
# 2026-01-29 23:54:18,153 - INFO - Source image dimensions: (512, 512, 129, 20)
# 2026-01-29 23:54:18,154 - INFO - Reference image dimensions: (256, 256, 152)
# 2026-01-29 23:54:18,256 - INFO - Saved support mask to /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/3d_cine_Amifer_full_fov_mask.nii.gz
# 2026-01-29 23:54:19,241 - INFO - Loaded 20 3D timepoints from source
# 2026-01-29 23:54:19,281 - INFO - Resampled timepoint 0 to reference FOV
# 2026-01-29 23:54:19,320 - INFO - Resampled timepoint 1 to reference FOV
# 2026-01-29 23:54:19,356 - INFO - Resampled timepoint 2 to reference FOV
# 2026-01-29 23:54:19,396 - INFO - Resampled timepoint 3 to reference FOV
# 2026-01-29 23:54:19,435 - INFO - Resampled timepoint 4 to reference FOV
# 2026-01-29 23:54:19,472 - INFO - Resampled timepoint 5 to reference FOV
# 2026-01-29 23:54:19,511 - INFO - Resampled timepoint 6 to reference FOV
# 2026-01-29 23:54:19,549 - INFO - Resampled timepoint 7 to reference FOV
# 2026-01-29 23:54:19,589 - INFO - Resampled timepoint 8 to reference FOV
# 2026-01-29 23:54:19,626 - INFO - Resampled timepoint 9 to reference FOV
# 2026-01-29 23:54:19,663 - INFO - Resampled timepoint 10 to reference FOV
# 2026-01-29 23:54:19,701 - INFO - Resampled timepoint 11 to reference FOV
# 2026-01-29 23:54:19,732 - INFO - Resampled timepoint 12 to reference FOV
# 2026-01-29 23:54:19,771 - INFO - Resampled timepoint 13 to reference FOV
# 2026-01-29 23:54:19,805 - INFO - Resampled timepoint 14 to reference FOV
# 2026-01-29 23:54:19,843 - INFO - Resampled timepoint 15 to reference FOV
# 2026-01-29 23:54:19,880 - INFO - Resampled timepoint 16 to reference FOV
# 2026-01-29 23:54:19,919 - INFO - Resampled timepoint 17 to reference FOV
# 2026-01-29 23:54:19,949 - INFO - Resampled timepoint 18 to reference FOV
# 2026-01-29 23:54:19,987 - INFO - Resampled timepoint 19 to reference FOV
# 2026-01-29 23:54:20,251 - INFO - Saved /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/3d_cine_Amifer_per_timepoint_full_fov/3d_cine_Amifer_frame_00.nii.gz
# 2026-01-29 23:54:20,479 - INFO - Saved /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/3d_cine_Amifer_per_timepoint_full_fov/3d_cine_Amifer_frame_01.nii.gz
# 2026-01-29 23:54:20,704 - INFO - Saved /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/3d_cine_Amifer_per_timepoint_full_fov/3d_cine_Amifer_frame_02.nii.gz
# 2026-01-29 23:54:20,936 - INFO - Saved /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/3d_cine_Amifer_per_timepoint_full_fov/3d_cine_Amifer_frame_03.nii.gz
# 2026-01-29 23:54:21,158 - INFO - Saved /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/3d_cine_Amifer_per_timepoint_full_fov/3d_cine_Amifer_frame_04.nii.gz
# 2026-01-29 23:54:21,381 - INFO - Saved /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/3d_cine_Amifer_per_timepoint_full_fov/3d_cine_Amifer_frame_05.nii.gz
# 2026-01-29 23:54:21,604 - INFO - Saved /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/3d_cine_Amifer_per_timepoint_full_fov/3d_cine_Amifer_frame_06.nii.gz
# 2026-01-29 23:54:21,827 - INFO - Saved /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/3d_cine_Amifer_per_timepoint_full_fov/3d_cine_Amifer_frame_07.nii.gz
# 2026-01-29 23:54:22,050 - INFO - Saved /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/3d_cine_Amifer_per_timepoint_full_fov/3d_cine_Amifer_frame_08.nii.gz
# 2026-01-29 23:54:22,273 - INFO - Saved /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/3d_cine_Amifer_per_timepoint_full_fov/3d_cine_Amifer_frame_09.nii.gz
# 2026-01-29 23:54:22,497 - INFO - Saved /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/3d_cine_Amifer_per_timepoint_full_fov/3d_cine_Amifer_frame_10.nii.gz
# 2026-01-29 23:54:22,719 - INFO - Saved /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/3d_cine_Amifer_per_timepoint_full_fov/3d_cine_Amifer_frame_11.nii.gz
# 2026-01-29 23:54:22,941 - INFO - Saved /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/3d_cine_Amifer_per_timepoint_full_fov/3d_cine_Amifer_frame_12.nii.gz
# 2026-01-29 23:54:23,163 - INFO - Saved /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/3d_cine_Amifer_per_timepoint_full_fov/3d_cine_Amifer_frame_13.nii.gz
# 2026-01-29 23:54:23,386 - INFO - Saved /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/3d_cine_Amifer_per_timepoint_full_fov/3d_cine_Amifer_frame_14.nii.gz
# 2026-01-29 23:54:23,610 - INFO - Saved /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/3d_cine_Amifer_per_timepoint_full_fov/3d_cine_Amifer_frame_15.nii.gz
# 2026-01-29 23:54:23,833 - INFO - Saved /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/3d_cine_Amifer_per_timepoint_full_fov/3d_cine_Amifer_frame_16.nii.gz
# 2026-01-29 23:54:24,060 - INFO - Saved /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/3d_cine_Amifer_per_timepoint_full_fov/3d_cine_Amifer_frame_17.nii.gz
# 2026-01-29 23:54:24,284 - INFO - Saved /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/3d_cine_Amifer_per_timepoint_full_fov/3d_cine_Amifer_frame_18.nii.gz
# 2026-01-29 23:54:24,512 - INFO - Saved /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/3d_cine_Amifer_per_timepoint_full_fov/3d_cine_Amifer_frame_19.nii.gz
# 2026-01-29 23:54:24,512 - INFO - Saved 20 resampled volumes
# 2026-01-29 23:54:24,738 - INFO - Successfully built 3D cine per timepoint (full FOV) for patient Amifer
# 2026-01-29 23:54:24,739 - INFO - Successfully built 3d cine per timepoint (full FOV) for patient Amifer
# 2026-01-29 23:54:24,739 - INFO - Building downsampled full FOV per timepoint (128x128x64) for patient Amifer
# 2026-01-29 23:54:24,927 - INFO - Source size: (256, 256, 152), spacing: (1.4062508344650269, 1.4062508344650269, 1.3999019861221313)
# 2026-01-29 23:54:24,928 - INFO - Target size: (128, 128, 64), spacing: (2.8125016689300537, 2.8125016689300537, 3.324767217040062)
# 2026-01-29 23:54:24,930 - INFO - Saved reference grid to /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/downsampled_full_fov_128x128x64/reference.nii.gz
# 2026-01-29 23:54:24,931 - INFO - Processing 4d_flow_mag...
# 2026-01-29 23:54:24,931 - INFO - Resampling 20 timepoints from /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_mag_Amifer_per_timepoint_full_fov
# 2026-01-29 23:54:26,714 - INFO - Saved 20 downsampled timepoints to /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/downsampled_full_fov_128x128x64/4d_flow_mag
# 2026-01-29 23:54:27,407 - INFO - Processing 4d_flow_vx...
# 2026-01-29 23:54:27,408 - INFO - Resampling 20 timepoints from /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vx_Amifer_per_timepoint_full_fov
# 2026-01-29 23:54:29,128 - INFO - Saved 20 downsampled timepoints to /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/downsampled_full_fov_128x128x64/4d_flow_vx
# 2026-01-29 23:54:29,140 - INFO - Processing 4d_flow_vy...
# 2026-01-29 23:54:29,140 - INFO - Resampling 20 timepoints from /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vy_Amifer_per_timepoint_full_fov
# 2026-01-29 23:54:30,820 - INFO - Saved 20 downsampled timepoints to /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/downsampled_full_fov_128x128x64/4d_flow_vy
# 2026-01-29 23:54:30,840 - INFO - Processing 4d_flow_vz...
# 2026-01-29 23:54:30,840 - INFO - Resampling 20 timepoints from /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vz_Amifer_per_timepoint_full_fov
# 2026-01-29 23:54:32,564 - INFO - Saved 20 downsampled timepoints to /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/downsampled_full_fov_128x128x64/4d_flow_vz
# 2026-01-29 23:54:32,600 - INFO - Processing 3d_cine...
# 2026-01-29 23:54:32,601 - INFO - Resampling 20 timepoints from /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/3d_cine_Amifer_per_timepoint_full_fov
# 2026-01-29 23:54:34,183 - INFO - Saved 20 downsampled timepoints to /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/downsampled_full_fov_128x128x64/3d_cine
# 2026-01-29 23:54:34,183 - INFO - Processing cine_mask...
# 2026-01-29 23:54:34,193 - INFO - Saved resampled cine mask to /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/downsampled_full_fov_128x128x64/3d_cine_mask_Amifer.nii.gz
# 2026-01-29 23:54:34,193 - INFO - Successfully built downsampled full FOV per timepoint (128x128x64) for patient Amifer
# 2026-01-29 23:54:34,196 - INFO - Successfully built downsampled full FOV per timepoint for patient Amifer
