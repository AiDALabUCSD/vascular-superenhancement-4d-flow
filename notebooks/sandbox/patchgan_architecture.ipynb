# %%
from torchinfo import summary
import torch.nn as nn
from vascular_superenhancement.training.model_factory import build_discriminator, PatchDiscriminator

# %%
model = PatchDiscriminator()
summary(model, input_size=(1, 3, 96, 96, 48))
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# PatchDiscriminator                       [1, 1, 11, 11, 5]         --
# ├─Sequential: 1-1                        [1, 1, 11, 11, 5]         --
# │    └─Conv3d: 2-1                       [1, 64, 48, 48, 24]       12,352
# │    └─LeakyReLU: 2-2                    [1, 64, 48, 48, 24]       --
# │    └─Conv3d: 2-3                       [1, 128, 24, 24, 12]      524,416
# │    └─BatchNorm3d: 2-4                  [1, 128, 24, 24, 12]      256
# │    └─LeakyReLU: 2-5                    [1, 128, 24, 24, 12]      --
# │    └─Conv3d: 2-6                       [1, 256, 12, 12, 6]       2,097,408
# │    └─BatchNorm3d: 2-7                  [1, 256, 12, 12, 6]       512
# │    └─LeakyReLU: 2-8                    [1, 256, 12, 12, 6]       --
# │    └─Conv3d: 2-9                       [1, 1, 11, 11, 5]         16,385
# ...
# Total params: 2,651,329
# Trainable params: 2,651,329
# Non-trainable params: 0
# ...

# %%
model = PatchDiscriminator(model_variant='C64k4s2-C128k4s1-C256k4s1-C1k4s2')
summary(model, input_size=(1, 3, 96, 96, 48))
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# PatchDiscriminator                       [1, 1, 23, 23, 11]        --
# ├─Sequential: 1-1                        [1, 1, 23, 23, 11]        --
# │    └─Conv3d: 2-1                       [1, 64, 48, 48, 24]       12,352
# │    └─LeakyReLU: 2-2                    [1, 64, 48, 48, 24]       --
# │    └─Conv3d: 2-3                       [1, 128, 47, 47, 23]      524,416
# │    └─BatchNorm3d: 2-4                  [1, 128, 47, 47, 23]      256
# │    └─LeakyReLU: 2-5                    [1, 128, 47, 47, 23]      --
# │    └─Conv3d: 2-6                       [1, 256, 46, 46, 22]      2,097,408
# │    └─BatchNorm3d: 2-7                  [1, 256, 46, 46, 22]      512
# │    └─LeakyReLU: 2-8                    [1, 256, 46, 46, 22]      --
# │    └─Conv3d: 2-9                       [1, 1, 23, 23, 11]        16,385
# ...
# Total params: 2,651,329
# Trainable params: 2,651,329
# Non-trainable params: 0
# ...
