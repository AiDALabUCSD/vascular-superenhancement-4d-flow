# %%
from vascular_superenhancement.utils.path_config import load_path_config
from vascular_superenhancement.data_management.patients import Patient

# Load config and create patient
path_config = load_path_config("all_patients")  # or your config name
patient = Patient(
    path_config=path_config,
    phonetic_id="Amifer",  # replace with your test patient
    overwrite_images=False,    # set to True to regenerate even if files exist
    debug=True,               # enable verbose logging
)

# Run just the per-timepoint pipeline
patient.build_per_timepoint_images()
# Out:
# Found project root at: /mnt/yeluru/vascular-superenhancement-4d-flow
# 2026-01-30 15:37:57,314 - DEBUG - Patient Amifer log file: /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/sample_patients/logs/patients/Amifer.log
# 2026-01-30 15:37:57,477 - DEBUG - Converted 3D Cine series number to integer: 900
# 2026-01-30 15:37:57,478 - DEBUG - Successfully initialized Amifer from database
# 2026-01-30 15:37:57,479 - INFO - Building per-timepoint volumes for patient Amifer
# 2026-01-30 15:37:57,479 - INFO - Building 3D cine volumes for each timepoint for patient Amifer
# 2026-01-30 15:37:57,479 - INFO - Output directory /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/3d_cine_Amifer_per_timepoint already exists and overwrite_images is False, skipping
# 2026-01-30 15:37:57,479 - INFO - Number of files in output directory: 20
# 2026-01-30 15:37:57,479 - INFO - Successfully built 3d cine per timepoint for patient Amifer
# 2026-01-30 15:37:57,480 - INFO - Building 4D flow volumes for each timepoint and component for patient Amifer
# 2026-01-30 15:37:57,781 - INFO - Loaded existing DICOM catalog for patient Amifer
# 2026-01-30 15:37:57,782 - INFO - Working on /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_mag_Amifer.nii.gz
# 2026-01-30 15:37:57,782 - INFO - Output directory /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_mag_Amifer_per_timepoint already exists and overwrite_images is False, skipping
# 2026-01-30 15:37:57,782 - INFO - Number of files in output directory: 20
# 2026-01-30 15:37:57,782 - INFO - Working on /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vx_Amifer.nii.gz
# 2026-01-30 15:37:57,782 - INFO - Output directory /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vx_Amifer_per_timepoint already exists and overwrite_images is False, skipping
# 2026-01-30 15:37:57,782 - INFO - Number of files in output directory: 20
# 2026-01-30 15:37:57,782 - INFO - Working on /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vy_Amifer.nii.gz
# 2026-01-30 15:37:57,782 - INFO - Output directory /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vy_Amifer_per_timepoint already exists and overwrite_images is False, skipping
# 2026-01-30 15:37:57,782 - INFO - Number of files in output directory: 20
# 2026-01-30 15:37:57,782 - INFO - Working on /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vz_Amifer.nii.gz
# 2026-01-30 15:37:57,783 - INFO - Output directory /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vz_Amifer_per_timepoint already exists and overwrite_images is False, skipping
# 2026-01-30 15:37:57,783 - INFO - Number of files in output directory: 20
# 2026-01-30 15:37:57,783 - INFO - Successfully built 4D flow volumes for each timepoint and component for patient Amifer
# 2026-01-30 15:37:57,783 - INFO - Successfully built 4d flow per timepoint for patient Amifer
# 2026-01-30 15:37:57,783 - INFO - Building speed volumes for each timepoint for patient Amifer
# 2026-01-30 15:37:57,783 - INFO - Output directory /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_speed_Amifer_per_timepoint already exists and overwrite_images is False, skipping
# 2026-01-30 15:37:57,783 - INFO - Number of files in output directory: 20
# 2026-01-30 15:37:57,783 - INFO - Successfully built speed per timepoint for patient Amifer
# 2026-01-30 15:37:57,783 - INFO - Building 4D flow volumes for each timepoint (full FOV) for patient Amifer
# 2026-01-30 15:37:57,783 - INFO - Working on /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_mag_Amifer.nii.gz (full FOV)
# 2026-01-30 15:37:57,783 - INFO - Output directory /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_mag_Amifer_per_timepoint_full_fov already exists and overwrite_images is False, skipping
# 2026-01-30 15:37:57,783 - INFO - Number of files in output directory: 20
# 2026-01-30 15:37:57,783 - INFO - Working on /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vx_Amifer.nii.gz (full FOV)
# 2026-01-30 15:37:57,784 - INFO - Output directory /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vx_Amifer_per_timepoint_full_fov already exists and overwrite_images is False, skipping
# 2026-01-30 15:37:57,784 - INFO - Number of files in output directory: 20
# 2026-01-30 15:37:57,784 - INFO - Working on /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vy_Amifer.nii.gz (full FOV)
# 2026-01-30 15:37:57,784 - INFO - Output directory /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vy_Amifer_per_timepoint_full_fov already exists and overwrite_images is False, skipping
# 2026-01-30 15:37:57,784 - INFO - Number of files in output directory: 20
# 2026-01-30 15:37:57,784 - INFO - Working on /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vz_Amifer.nii.gz (full FOV)
# 2026-01-30 15:37:57,784 - INFO - Output directory /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/4d_flow_vz_Amifer_per_timepoint_full_fov already exists and overwrite_images is False, skipping
# 2026-01-30 15:37:57,784 - INFO - Number of files in output directory: 20
# 2026-01-30 15:37:57,784 - INFO - Successfully built 4D flow volumes (full FOV) for each timepoint for patient Amifer
# 2026-01-30 15:37:57,784 - INFO - Successfully built 4d flow per timepoint (full FOV) for patient Amifer
# 2026-01-30 15:37:57,784 - INFO - Building 3D cine per timepoint (full FOV) for patient Amifer
# 2026-01-30 15:37:57,784 - INFO - Output directory /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/3d_cine_Amifer_per_timepoint_full_fov already has 20 files and mask exists. overwrite_images is False, skipping.
# 2026-01-30 15:37:57,784 - INFO - Successfully built 3d cine per timepoint (full FOV) for patient Amifer
# 2026-01-30 15:37:57,784 - INFO - Building downsampled full FOV per timepoint (128x128x64) for patient Amifer
# 2026-01-30 15:37:58,137 - INFO - Source size: (256, 256, 152), spacing: (1.4062508344650269, 1.4062508344650269, 1.3999019861221313)
# 2026-01-30 15:37:58,137 - INFO - Target size: (128, 128, 64), spacing: (2.8125016689300537, 2.8125016689300537, 3.324767217040062)
# 2026-01-30 15:37:58,138 - INFO - Output subdir /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/downsampled_full_fov_128x128x64/4d_flow_mag already has 20 files, skipping 4d_flow_mag
# 2026-01-30 15:37:58,138 - INFO - Output subdir /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/downsampled_full_fov_128x128x64/4d_flow_vx already has 20 files, skipping 4d_flow_vx
# 2026-01-30 15:37:58,138 - INFO - Output subdir /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/downsampled_full_fov_128x128x64/4d_flow_vy already has 20 files, skipping 4d_flow_vy
# 2026-01-30 15:37:58,139 - INFO - Output subdir /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/downsampled_full_fov_128x128x64/4d_flow_vz already has 20 files, skipping 4d_flow_vz
# 2026-01-30 15:37:58,139 - INFO - Output subdir /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/downsampled_full_fov_128x128x64/3d_cine already has 20 files, skipping 3d_cine
# 2026-01-30 15:37:58,139 - INFO - Cine mask already exists at /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/downsampled_full_fov_128x128x64/3d_cine_mask_Amifer.nii.gz, skipping
# 2026-01-30 15:37:58,153 - INFO - Computing speed from downsampled velocity components...
# 2026-01-30 15:38:00,913 - INFO - Saved 20 speed volumes to /home/ayeluru/vascular-superenhancement-4d-flow/working_dir/all_patients/patient_data/Amifer/nifti/downsampled_full_fov_128x128x64/4d_flow_speed
# 2026-01-30 15:38:00,913 - INFO - Successfully built downsampled full FOV per timepoint (128x128x64) for patient Amifer
# 2026-01-30 15:38:00,915 - INFO - Successfully built downsampled full FOV per timepoint for patient Amifer
